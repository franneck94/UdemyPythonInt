# %% [markdown]
# ### Named Tuple
#
# Tuple subclasses with named fields
#
# - immutable
# - hashable
# - **\_\_repr\_\_**, **\_\_str\_\_** and compare defined
# - Support indexing

# %%
from collections import namedtuple
from typing import NamedTuple
from typing import TypedDict

# %% [markdown]
# NamedTuple Collection

# %%
User = namedtuple(
    'User',
    ['name', 'age', 'is_admin']
)

# %%
user_jan = User(
    name='Jan',
    age=28,
    is_admin=True,
)

# %%
print(user_jan)
# Out:
# User(name='Jan', age=28, is_admin=True)

# %% [markdown]
# NamedTuple Type

# %%
class User(NamedTuple):
    name: str
    age: int
    is_admin: bool = False

# %%
user_jan = User('Jan', 28, True)

# %%
print(user_jan)
# Out:
# User(name='Jan', age=28, is_admin=True)

# %% [markdown]
# TypedDict

# %%
class User(TypedDict):
    name: str
    age: int
    is_admin: bool

# %%
user_jan = {'name': 'Jan', 'age': 28, 'is_admin': True}

# %%
print(user_jan)
# Out:
# {'name': 'Jan', 'age': 28, 'is_admin': True}
